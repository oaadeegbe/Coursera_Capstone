# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## 1. Introduction/Business Problem

# %% [markdown]
# In this project, we shall be considering two locations; Houston, TX, and New York, NY. The idea behind this is to firstly compare the business types using Foursquare location data.
#
# [The Top 10 Largest Cities in the U.S. by Population](https://www.moving.com/tips/the-top-10-largest-us-cities-by-population/) ranks New York City as number one and ranks Houston as number four, with over 8 million and over 2 million inhabitants respectively. The article also details New York as one of the largest financial hubs in the world and Houston as one of the best places for business.
#
# Due to this, we have decided to compare these two cities to review the top business types by number of businesses under those types. Using that information, we will also be recommending business types to potential investors who want to invest in these choice locations.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# For this project, we will be utilizing the Foursquare API to fetch location data of both Houston and New York. To start with, we will geolocate both cities using the geopy library. These location points (latitude and longitude) will then be combined with other essential parameters to be used for the Foursquare API.
#
# The fetched data will, which comes in JSON format will then be converted to a dataframe (with the location points merged to its respective location) containing just the essential data columns such as id, name, address, city, state, country, latitude, longitude, postal code, and business types.
#
# As mentioned in the Introduction/Business Problem section, these dataframes for both cities will help us determine the top business in both cities and as well help us recommend business types to potential investors.

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# Using the foursquare API, we will be extracting and reviewing the location data of Houston and New York (our reference locations), which details various location properties. As mentioned in the Data section, we will extract just the essential or needed properties for use in this project. Also, on reviewing the data we ranked the the business types and their count in both locations, to give us an idea of the most common or top ranked businesses in those areas.
#
# After all these are done, we apply K-Means Clustering Technique to cluster the businesses in terms of postal code (which is relative since similar locations mostly share same zip code). On the otherhand, we tried other feasible means of categorization such as business types, which didn't yield reasonable clusters. This is the reason why the postal code clusters was a better option.

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

import json

#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim

import requests
from pandas.io.json import json_normalize


import matplotlib.cm as cm
import matplotlib.colors as colors


from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentials have been stored!

# %%
def query(queryname, radius, limit):
    '''
    This function takes in a location name and radius, and uses this location name to generate a central latitude and longitude,
    which is used to extract the business/buildings/addresses in a specified radius to the central point.
    
    data: queryname is a string type input of location name
          radius is an integer type input of radius of coverage from central point
          limit  is an integer type input of the number of locations fetched from the url using Foursquare API
    '''
    print('The location is:', queryname)
    
    
    #Use the location name to extract the location latitude and longitude
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(queryname)
    latitude = location.latitude
    longitude = location.longitude
    print('The Latitude is: ', latitude, 'the Longitude is: ', longitude)
    
    
    #using the latitude and longitude, create the foursquare API url where the location data will be extracted/requested from
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, limit)
    #print(url, '\n')
    
    
    #get the location data in JSON format using Foursquare API
    results_json = requests.get(url).json()
    
    #format the queried json data for the required useful data
    query_json = results_json['response']['venues']
    
    #transform the formatted json data into a dataframe
    df = json_normalize(query_json)

    #filter the dataframe to extract essential location data
    formatted_df = df[['id', 'name', 'location.address', 'location.city', 'location.state', 'location.cc', 'location.lat', 'location.lng', 'location.postalCode']]
    
    #extra location data are found in the categories column, which will be formatted to be included in the final dataframe
    categories = df['categories']
    
    business = []
    pluralBusiness = []

    for each in categories:
        #print(each)
        if len(each) == 0:
            pass
        else:
            business.append(each[0]['name'])
            pluralBusiness.append(each[0]['pluralName'])

    #print(business)
    #print(pluralBusiness)

    names_dict = {'type': business, 'plural': pluralBusiness}
    names_df = pd.DataFrame(names_dict)
    
    #combine the formatted dataframe and the extra location dataframe into the final dataframe to be used for the project
    final_df = formatted_df.join(names_df)
    
    final_df = final_df.rename(columns = {'location.address': 'address', 'location.city': 'city', 'location.state': 'state', 'location.cc': 'country', 'location.lat': 'latitude', 'location.lng': 'longitude', 'location.postalCode': 'postalCode'})
    
    #drop locations with no known addresses
    final_df = final_df.dropna()
    
    #drop locations not matching the specific queryname location i.e. New York or Houston
    final_df = final_df[final_df['city'] == queryname[:-4]]
    
    return final_df, [latitude, longitude]

# %%
newyork = query('New York, NY', radius = 1500, limit = 300)[0]

newyork.head()
# Out:
# The location is: New York, NY
# The Latitude is:  40.7127281 the Longitude is:  -74.0060152
# New York
#                          id                        name  \
# 0  4a676321f964a52051c91fe3          New York City Hall
# 1  3fd66200f964a520d8f11ee3              City Hall Park
# 3  4b79a5e8f964a52037082fe3                NY Gift Shop
# 4  51a4bc7c498e469047be66d6  City Hall Council Chambers
# 5  5d25d7fd3221cb002471e7c8             City Hall Plaza
#
#                  address      city state country   latitude  longitude  \
# 0         260 E Broadway  New York    NY      US  40.712659 -74.005880
# 1            17 Park Row  New York    NY      US  40.712415 -74.006724
# 3           234 Canal St  New York    NY      US  40.712733 -74.005978
# 4              City Hall  New York    NY      US  40.712736 -74.005472
# 5  Steve Flanders Square  New York    NY      US  40.712641 -74.006131
#
#   postalCode       type      plural
# 0      10002  City Hall  City Halls
# 1      10038       Park       Parks
# 3      10013  Gift Shop  Gift Shops
# 4      10007  City Hall  City Halls
# 5      10007      Plaza      Plazas

# %%
houston = query('Houston, TX', radius = 1500, limit = 300)[0]

houston.head()
# Out:
# The location is: Houston, TX
# The Latitude is:  29.7589382 the Longitude is:  -95.3676974
# Houston
#                          id              name           address     city  \
# 0  4cbf112b00d837047b8a415c   Baker Botts LLP  910 Louisiana St  Houston
# 1  5b3b978a56ca62001c94580e  Nrg Energy, Inc.  910 Louisiana St  Houston
# 2  4b993b14f964a520d76b35e3   One Shell Plaza  910 Louisiana St  Houston
# 3  527096a111d2393d1fc331aa  The Houston Club  920 Louisiana St  Houston
# 4  4b9ff072f964a520224c37e3         Starbucks  3801 Cullen Blvd  Houston
#
#   state country   latitude  longitude postalCode             type  \
# 0    TX      US  29.759671 -95.367728      77002  Conference Room
# 1    TX      US  29.759544 -95.367348      77002           Office
# 2    TX      US  29.759283 -95.367858      77002           Office
# 3    TX      US  29.759112 -95.367565      77002       Restaurant
# 4    TX      US  29.759090 -95.367500      77004      Coffee Shop
#
#              plural
# 0  Conference Rooms
# 1           Offices
# 2           Offices
# 3       Restaurants
# 4      Coffee Shops

# %%
def businessTypes(dataframe):
    
    dataframe_count = (pd.DataFrame(dataframe['plural'].value_counts())).reset_index()
    dataframe_count = dataframe_count.rename(columns = {'index': 'businessType', 'plural': 'Count'})
    
    dataframe_keys = dataframe_count['businessType'].to_list()
    
    length = dataframe_count.count()[0]

    dataframe_dict = {}

    for i in range(length):
        key = dataframe_count['businessType'].iloc[i]
        value = dataframe_count['Count'].iloc[i]
        dataframe_dict[key] = value
        
    return dataframe_count, dataframe_keys, dataframe_dict

# %%
def map_plot(location, dataframe):

    # create map using latitude and longitude values
    map_plot = folium.Map(location, zoom_start=50)

    # add markers to map
    for lat, lng, name, typ in zip(dataframe['latitude'], dataframe['longitude'], dataframe['name'], dataframe['type']):
        label = "{}, ({})".format(name, typ)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat, lng], radius=5, popup=label, color='red', fill=True, fill_color='white', fill_opacity=0.7, parse_html=False).add_to(map_plot)

    return map_plot

# %%
def cluster(dataframe):
    grouped = dataframe[['id', 'name', 'type']].groupby('type').count()
    grouped = grouped.sort_values(by = 'name', ascending = False)
    #print(grouped)
    
    dummies = pd.get_dummies(dataframe['name'])
    dummies = dataframe[['postalCode']].join(dummies)
    dummies = dummies.groupby('postalCode').mean().reset_index()
    #print(dummies.head())

    kclusters = len(dataframe['postalCode'].unique())
    
    kmeans_group = dummies.drop('postalCode', axis = 1)
    #print(kmeans_group.head())
    
    kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(kmeans_group)
    print(kmeans.labels_)
    
    dummies.insert(0, 'Cluster Labels', kmeans.labels_)

    cluster_df = dummies[['Cluster Labels', 'postalCode']]
    final_df = dataframe.merge(cluster_df, how = 'right')
    
    return final_df

# %%
def cluster_map(location, dataframe):
    map_clusters = folium.Map(location, zoom_start=50)
    
    kclusters = len(dataframe['postalCode'].unique())
    
    # set color scheme for the clusters
    x = np.arange(kclusters)
    ys = [i + x + (i*x)**2 for i in range(kclusters)]
    colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
    rainbow = [colors.rgb2hex(i) for i in colors_array]

    # add markers to the map
    markers_colors = []

    for lat, lon, point, cluster in zip(dataframe['latitude'], dataframe['longitude'], dataframe['postalCode'], dataframe['Cluster Labels']):
        label = folium.Popup(str(point) + ' : Cluster ' + str(cluster), parse_html=True)
        folium.CircleMarker([lat, lon], radius=5, popup=label, color=rainbow[cluster-1], fill=True, fill_color=rainbow[cluster-1], fill_opacity=0.9).add_to(map_clusters)


    return map_clusters

# %% [markdown]
# ## 4. Results

# %% [markdown]
# Upon extraction and analysis of both locations (i.e. Houston and New York), firstly we discovered that the extracted data contained closer locations such as San Antonio, or didn't contain an address, as such couldn't be referenced, etc. A lot of these unwanted or wrong data, were dropped so as not to affect the analysis or decision making process. Secondly, in both locations, we discovered that Office buildings (under business type) were the most common businesses, followed by office-related buildings such as Banks, other type of Buildings, Conference rooms, etc.
#
# Thirdly, as mentioned in the methodology, we applied K-Means Clustering, which focused on the postal codes as against the thoughtful business types, which yielded non-ideal clusters. These clusters for both locations are shown in the maps shown.

# %%
houston_count = businessTypes(houston)[0] #total number of business types per business
houston_keys = businessTypes(houston)[1] #business types
houston_dict = businessTypes(houston)[2] #business type dictionary, using keys from above

print(houston_dict, '\n')
houston_count.head(10)
# Out:
# {'Offices': 10, 'Bus Lines': 5, 'Buildings': 5, 'Banks': 4, 'Bus Stations': 3, 'Conference Rooms': 3, 'Food Trucks': 3, 'Gyms': 2, 'Delis / Bodegas': 2, 'Parking': 2, 'Coffee Shops': 2, 'Plazas': 1, "Dentist's Offices": 1, 'Art Galleries': 1, 'Gyms or Fitness Centers': 1, 'Restaurants': 1, 'Farmers Markets': 1, 'Optical Shops': 1, 'Event Spaces': 1, 'Lounges': 1, 'Taco Places': 1, 'Sandwich Places': 1, 'Weight Loss Centers': 1, 'Miscellaneous Shops': 1, 'Professional & Other Places': 1, 'Performing Arts Venues': 1, 'Cafés': 1, 'Breakfast Spots': 1, 'Auditoriums': 1, 'Nightclubs': 1, 'Thai Restaurants': 1, 'Libraries': 1, 'Bakeries': 1, 'American Restaurants': 1, 'Parks': 1, 'Fast Food Restaurants': 1}
#        businessType  Count
# 0           Offices     10
# 1         Bus Lines      5
# 2         Buildings      5
# 3             Banks      4
# 4      Bus Stations      3
# 5  Conference Rooms      3
# 6       Food Trucks      3
# 7              Gyms      2
# 8   Delis / Bodegas      2
# 9           Parking      2

# %%
newyork_count = businessTypes(newyork)[0] #total number of business types per business
newyork_keys = businessTypes(newyork)[1] #business types
newyork_dict = businessTypes(newyork)[2] #business type dictionary, using keys from above

print(newyork_dict, '\n')
newyork_count.head(10)
# Out:
# {'Offices': 5, 'College Classrooms': 4, 'Buildings': 2, 'Bus Stations': 2, 'Parks': 2, 'Government Buildings': 2, 'Bus Stops': 2, 'College Theaters': 2, 'City Halls': 2, 'Pizza Places': 2, 'Plazas': 2, 'College Bookstores': 1, 'Jewelry Stores': 1, 'Farmers Markets': 1, 'Perfume Shops': 1, 'Bookstores': 1, 'Music Venues': 1, 'Arts & Crafts Stores': 1, 'Dessert Shops': 1, 'Metro Stations': 1, 'Student Centers': 1, 'College Administrative Buildings': 1, 'Professional & Other Places': 1, 'Coworking Spaces': 1, 'Beer Stores': 1, 'Miscellaneous Shops': 1, 'Gift Shops': 1, 'Kofte Places': 1, 'Thai Restaurants': 1, 'Monuments / Landmarks': 1, 'Islands': 1, 'Public Art': 1, 'Ice Cream Shops': 1, 'Strip Clubs': 1, 'Lawyers': 1, 'College Labs': 1, 'Mexican Restaurants': 1, 'Food Trucks': 1, 'Indian Restaurants': 1}
#            businessType  Count
# 0               Offices      5
# 1    College Classrooms      4
# 2             Buildings      2
# 3          Bus Stations      2
# 4                 Parks      2
# 5  Government Buildings      2
# 6             Bus Stops      2
# 7      College Theaters      2
# 8            City Halls      2
# 9          Pizza Places      2

# %%
unique_keys = list(set(houston_keys + newyork_keys))
print(unique_keys)
# Out:
# ['Indian Restaurants', "Dentist's Offices", 'Conference Rooms', 'Taco Places', 'Jewelry Stores', 'Art Galleries', 'Arts & Crafts Stores', 'College Bookstores', 'Optical Shops', 'Event Spaces', 'Perfume Shops', 'Banks', 'Metro Stations', 'Plazas', 'College Theaters', 'College Labs', 'Parking', 'City Halls', 'Coworking Spaces', 'Lounges', 'Performing Arts Venues', 'Cafés', 'Breakfast Spots', 'Gift Shops', 'Thai Restaurants', 'Libraries', 'Student Centers', 'Monuments / Landmarks', 'Public Art', 'Ice Cream Shops', 'Bus Stations', 'Miscellaneous Shops', 'Lawyers', 'American Restaurants', 'Gyms', 'Offices', 'Beer Stores', 'Sandwich Places', 'Bus Lines', 'Music Venues', 'Bookstores', 'Restaurants', 'Farmers Markets', 'Pizza Places', 'College Administrative Buildings', 'College Classrooms', 'Bus Stops', 'Dessert Shops', 'Gyms or Fitness Centers', 'Weight Loss Centers', 'Strip Clubs', 'Coffee Shops', 'Auditoriums', 'Fast Food Restaurants', 'Professional & Other Places', 'Government Buildings', 'Nightclubs', 'Kofte Places', 'Bakeries', 'Islands', 'Mexican Restaurants', 'Parks', 'Food Trucks', 'Delis / Bodegas', 'Buildings']

# %%
full_dict = {}

for each in unique_keys:
    if each in houston_keys and each not in newyork_keys:
        value = houston_dict[each]
    elif each in houston_keys and each in newyork_keys:
        value = houston_dict[each] + newyork_dict[each]
    elif each not in houston_keys and each in newyork_keys:
        value = newyork_dict[each]
    
    full_dict[each] = value

print(full_dict)
# Out:
# {'Indian Restaurants': 1, "Dentist's Offices": 1, 'Conference Rooms': 3, 'Taco Places': 1, 'Jewelry Stores': 1, 'Art Galleries': 1, 'Arts & Crafts Stores': 1, 'College Bookstores': 1, 'Optical Shops': 1, 'Event Spaces': 1, 'Perfume Shops': 1, 'Banks': 4, 'Metro Stations': 1, 'Plazas': 3, 'College Theaters': 2, 'College Labs': 1, 'Parking': 2, 'City Halls': 2, 'Coworking Spaces': 1, 'Lounges': 1, 'Performing Arts Venues': 1, 'Cafés': 1, 'Breakfast Spots': 1, 'Gift Shops': 1, 'Thai Restaurants': 2, 'Libraries': 1, 'Student Centers': 1, 'Monuments / Landmarks': 1, 'Public Art': 1, 'Ice Cream Shops': 1, 'Bus Stations': 5, 'Miscellaneous Shops': 2, 'Lawyers': 1, 'American Restaurants': 1, 'Gyms': 2, 'Offices': 15, 'Beer Stores': 1, 'Sandwich Places': 1, 'Bus Lines': 5, 'Music Venues': 1, 'Bookstores': 1, 'Restaurants': 1, 'Farmers Markets': 2, 'Pizza Places': 2, 'College Administrative Buildings': 1, 'College Classrooms': 4, 'Bus Stops': 2, 'Dessert Shops': 1, 'Gyms or Fitness Centers': 1, 'Weight Loss Centers': 1, 'Strip Clubs': 1, 'Coffee Shops': 2, 'Auditoriums': 1, 'Fast Food Restaurants': 1, 'Professional & Other Places': 2, 'Government Buildings': 2, 'Nightclubs': 1, 'Kofte Places': 1, 'Bakeries': 1, 'Islands': 1, 'Mexican Restaurants': 1, 'Parks': 3, 'Food Trucks': 4, 'Delis / Bodegas': 2, 'Buildings': 7}

# %%
df_dict = {'businessType': list(full_dict.keys()), 'Count': list(full_dict.values())}
business_df = (pd.DataFrame(df_dict).sort_values(by = 'Count', ascending=False)).reset_index()
business_df = business_df.drop(columns = 'index')
business_df.head(10)
# Out:
#          businessType  Count
# 0             Offices     15
# 1           Buildings      7
# 2        Bus Stations      5
# 3           Bus Lines      5
# 4               Banks      4
# 5  College Classrooms      4
# 6         Food Trucks      4
# 7              Plazas      3
# 8               Parks      3
# 9    Conference Rooms      3

# %%
ny_location = query('New York, NY', radius = 1500, limit = 300)[1]
hs_location = query('Houston, TX', radius = 1500, limit = 300)[1]
# Out:
# The location is: New York, NY
# The Latitude is:  40.7127281 the Longitude is:  -74.0060152
# New York
# The location is: Houston, TX
# The Latitude is:  29.7589382 the Longitude is:  -95.3676974
# Houston

# %%
map_plot(ny_location, newyork)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_plot(hs_location, houston)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
houston_cluster = cluster(houston)
houston_cluster
# Out:
# [2 5 4 7 6 0 3 1 8]
#                           id                                           name  \
# 0   4cbf112b00d837047b8a415c                                Baker Botts LLP
# 1   5b3b978a56ca62001c94580e                               Nrg Energy, Inc.
# 2   4b993b14f964a520d76b35e3                                One Shell Plaza
# 3   527096a111d2393d1fc331aa                               The Houston Club
# 4   4e3def4f62e19d6109763188                                 Hermann Square
# 5   4b73281af964a520d09e2de3                               The Houston Club
# 6   4baa6bd3f964a52089683ae3                              Wells Fargo Plaza
# 7   4ae4e065f964a5200d9f21e3           Hobby Center for the Performing Arts
# 8   58f648e7588e3646b4ca9a0c                                  Tacos A Go Go
# 9   527aca1c11d26f356c4b3840                      One Shell Wellness Center
# 10  4ba8be39f964a5207ceb39e3                                  Murphy's Deli
# 11  4ec086b3c2ee23891e64d0f9                                  Goldman Sachs
# 12  548f6037498e6422689c3775                                       PwC, LLP
# 13  5e28dbbfd7f28c0008e17db6                                 Adair Downtown
# 14  583491fb409f5673e5c8440f                                 5411 Empanadas
# 15  4bd894b751170f4790bb33e4                                 Paradise Gifts
# 16  4b7b0054f964a5204f4b2fe3                                Thai Spice Cafe
# 17  5bad209ce65d0c002c4e9a0c                                         Stifel
# 18  4be80ef588ed2d7fb25ecb1d                     Kolache Factory - Downtown
# 19  4fe33d1d754a0767553dc6d3            Which Wich - Kinder Morgan Building
# 20  4ecfcabdb8f7971d69db854d                                 Susman Godfrey
# 21  4e989c036da1ff6171d9a5be                                 Nextera Energy
# 22  4df2571318386ecb4e2c1480                Metro Stop - Louisiana / Mckney
# 23  4ecbe13a2c5be0e01cbcd940                                          Page/
# 24  4b58859df964a520ef5b28e3                                     McDonald's
# 25  4f4178aae4b0740e7be4adb9                         Downtown Club At Plaza
# 26  4f622f856d86426416f23d37                       District 7 Grill-Tunnels
# 27  4b5878a5f964a520525928e3                          Seattle's Best Coffee
# 28  5062190de4b0f99621494e81                          Metro Bus Shelter 579
# 29  4cb5fcd156fca1cd6e065318                        Urban Harvest City Hall
# 30  4fc8e5a0e4b0665181fd37b7                            Surface Parking Lot
# 31  4dffa581ae605b47b17648e5                   Patrick J. McClellan, D.D.S.
# 32  4bba16f13db7b7138ae0229a                               Chicken Etcetera
# 33  509c6c29e4b0eac4e468d491                                   Morgan Lewis
# 34  4bc6191a51b376b0b9fb1a6f                         Well's Fargo Sky Lobby
# 35  4b2298fff964a520d74924e3                                 The Plaza Club
# 36  4d0796c9dc45a093298af9c6                                Global Crossing
# 37  4fce50e4d5fbe1bff3913178        Steele Door Repair Company and Supplier
# 38  4d94e045b550a0930faa9087                               Standard Parking
# 39  50e17952e4b053b5fd640107                 Wells Fargo Plaza Loading Dock
# 40  59e0f1ca1c0b341a792ab1bc                       Cool Runnings Food Truck
# 41  521fbe2811d25489e10ca2ea                                       Fotofest
# 42  5d37c2831d74df0008979755                      Wells Fargo Home Mortgage
# 43  5356a731498e03ae387854dc                                 DLA Piper, LLP
# 44  4f2999ede4b05879eb1ff4a4                              ZAAZ Studios 1001
# 45  53593b97498e875e1312922d                        Weight Watchers at Work
# 46  5181629c498ed559a6c9182b  Wells Fargo Plaza Sky Lobby 58th & 59th Floor
# 47  50abc4f4e4b017117220e8ad                                  Conf Room 536
# 48  4b26fb5ef964a520b18324e3                          Martha Hermann Square
# 49  51dbfcf5498ee0bb9ae1e3ce                            Ryder Scott Company
# 50  4e666d5218384a9e6a631a3e                               The Medley Group
# 51  4d60182f1ee8721edd8ca621                        Datacenter @ 777 Walker
# 52  4d38bfa20a288cfada52833c                    Houstonian Lite Wells Fargo
# 53  50831472e4b0fedebe241e8b                      611 Walker Parking Garage
# 54  4e9f148593ad5d11f3d5d278                                    Dune Energy
# 55  53177309498e9acc4d1a24ad                       OSP 6th Floor Energy Hub
# 56  53aad44b498e19106dc769b5                           Enable Midstream LLP
# 57  4b9ff072f964a520224c37e3                                      Starbucks
# 58  59947f66be70787754930c95                              Story Ultralounge
# 59  589e46f472714f7d35e789fa                             My Hoa Food Market
# 60  584fa9cb9c439d6c43faddc0                                   Sprint Store
# 61  57f5f63a498e5a12ebf0a681                                Citizen Pilates
# 62  593a07ec2ebb34774fa19acf                                  Mira Eye Care
# 63  521ed0488bbd87164effb765                                   Electric Now
# 64  4baa452bf964a52091593ae3                      Patrick J. McClellan, DDS
# 65  4d3a1dbb687ca35d843a86c4                                  Frosted Betty
#
#                          address     city state country   latitude  longitude  \
# 0               910 Louisiana St  Houston    TX      US  29.759671 -95.367728
# 1               910 Louisiana St  Houston    TX      US  29.759544 -95.367348
# 2               910 Louisiana St  Houston    TX      US  29.759283 -95.367858
# 3               920 Louisiana St  Houston    TX      US  29.759112 -95.367565
# 4                   900 Smith St  Houston    TX      US  29.759800 -95.368543
# 5      910 Louisiana St Ste 4900  Houston    TX      US  29.759041 -95.367777
# 6              1000 Louisiana St  Houston    TX      US  29.758619 -95.368399
# 7                   800 Bagby St  Houston    TX      US  29.761526 -95.369376
# 8               910 Louisiana St  Houston    TX      US  29.759125 -95.367525
# 9               910 Louisiana St  Houston    TX      US  29.759373 -95.367615
# 10              910 Louisiana St  Houston    TX      US  29.758974 -95.367215
# 11     1000 Louisiana St Ste 550  Houston    TX      US  29.758429 -95.368294
# 12             1000 Louisiana St  Houston    TX      US  29.758559 -95.368084
# 13             1000 Louisiana St  Houston    TX      US  29.758268 -95.368372
# 14              811 Louisiana St  Houston    TX      US  29.758986 -95.368590
# 15                 777 Walker St  Houston    TX      US  29.759278 -95.367327
# 16           777 Walker St M 130  Houston    TX      US  29.757305 -95.368824
# 17                1000 Lousiania  Houston    TX      US  29.758471 -95.368473
# 18              811 Louisiana St  Houston    TX      US  29.759313 -95.366217
# 19             1001 Louisiana St  Houston    TX      US  29.758183 -95.367845
# 20       1200 Louisiana St #5100  Houston    TX      US  29.758170 -95.368571
# 21             1000 Louisiana St  Houston    TX      US  29.758333 -95.368135
# 22              910 Louisiana St  Houston    TX      US  29.758972 -95.367667
# 23             1100 Louisiana St  Houston    TX      US  29.758473 -95.368543
# 24                    777 Walker  Houston    TX      US  29.759185 -95.366269
# 25              910 Louisiana St  Houston    TX      US  29.759150 -95.367676
# 26         1001 Louisiana St B30  Houston    TX      US  29.758245 -95.367539
# 27                 777 Walker St  Houston    TX      US  29.759223 -95.367046
# 28                     Louisiana  Houston    TX      US  29.758896 -95.367884
# 29                  900 Bagby St  Houston    TX      US  29.759237 -95.368160
# 30                    701 Walker  Houston    TX      US  29.759168 -95.367639
# 31      910 Louisiana St Ste 190  Houston    TX      US  29.758976 -95.367853
# 32                 777 Walker St  Houston    TX      US  29.759418 -95.366876
# 33             1000 Louisiana St  Houston    TX      US  29.758429 -95.368294
# 34            2000 Louisiana St.  Houston    TX      US  29.758879 -95.367955
# 35              910 Louisiana St  Houston    TX      US  29.759385 -95.366821
# 36                 777 Walker St  Houston    TX      US  29.758265 -95.367479
# 37              862 Louisiana St  Houston    TX      US  29.759367 -95.366886
# 38                    701 Walker  Houston    TX      US  29.758807 -95.368313
# 39             1000 Louisiana St  Houston    TX      US  29.758588 -95.368661
# 40                        Dallas  Houston    TX      US  29.759188 -95.368415
# 41                 1600 Smith St  Houston    TX      US  29.758896 -95.367153
# 42             1000 Louisiana St  Houston    TX      US  29.758531 -95.368476
# 43    1000 Louisiana St Ste 2800  Houston    TX      US  29.758539 -95.367569
# 44  611 Clay S. Louisiana Tunnel  Houston    TX      US  29.759020 -95.367699
# 45             1100 Louisiana St  Houston    TX      US  29.758663 -95.367647
# 46             1000 Louisiana St  Houston    TX      US  29.758323 -95.368359
# 47                 611 Walker St  Houston    TX      US  29.758991 -95.368569
# 48                 901 Smith St.  Houston    TX      US  29.759706 -95.368349
# 49        1100 Louisiana St #460  Houston    TX      US  29.759221 -95.368052
# 50                 815 Walker St  Houston    TX      US  29.758325 -95.368354
# 51                 777 Walker St  Houston    TX      US  29.758376 -95.367746
# 52    1000 Louisiana St Ste 1450  Houston    TX      US  29.759027 -95.367669
# 53                 611 Walker St  Houston    TX      US  29.758475 -95.367694
# 54          777 Walker St Ste 23  Houston    TX      US  29.759130 -95.366494
# 55              910 Louisiana St  Houston    TX      US  29.758767 -95.366854
# 56             1111 Louisiana St  Houston    TX      US  29.758135 -95.367301
# 57              3801 Cullen Blvd  Houston    TX      US  29.759090 -95.367500
# 58                3302 Mercer St  Houston    TX      US  29.759177 -95.367444
# 59           13201 Bellaire Blvd  Houston    TX      US  29.759832 -95.368345
# 60           14418 Bellaire Blvd  Houston    TX      US  29.759456 -95.367401
# 61              3217 Houston Ave  Houston    TX      US  29.758901 -95.366671
# 62         5819 Gulf Fwy Ste 700  Houston    TX      US  29.758785 -95.368001
# 63       2105 Citywest Blvd #100  Houston    TX      US  29.759157 -95.367025
# 64               190 Shell Plaza  Houston    TX      US  29.758480 -95.368264
# 65              833 Studewood St  Houston    TX      US  29.784962 -95.387678
#
#    postalCode                         type                       plural  \
# 0       77002              Conference Room             Conference Rooms
# 1       77002                       Office                      Offices
# 2       77002                       Office                      Offices
# 3       77002                   Restaurant                  Restaurants
# 4       77002                         Park                        Parks
# 5       77002                       Office                      Offices
# 6       77002                       Office                      Offices
# 7       77002        Performing Arts Venue       Performing Arts Venues
# 8       77002                   Taco Place                  Taco Places
# 9       77002                          Gym                         Gyms
# 10      77002                Deli / Bodega              Delis / Bodegas
# 11      77002                         Bank                        Banks
# 12      77002                       Office                      Offices
# 13      77002                         Café                        Cafés
# 14      77002                     Building                    Buildings
# 15      77002              Thai Restaurant             Thai Restaurants
# 16      77002                       Office                      Offices
# 17      77002               Breakfast Spot              Breakfast Spots
# 18      77002               Sandwich Place              Sandwich Places
# 19      77002                      Library                    Libraries
# 20      77002                       Office                      Offices
# 21      77002                     Bus Line                    Bus Lines
# 22      77002                       Office                      Offices
# 23      77002         Fast Food Restaurant        Fast Food Restaurants
# 24      77002                  Event Space                 Event Spaces
# 25      77002          American Restaurant         American Restaurants
# 26      77002                  Coffee Shop                 Coffee Shops
# 27      77002                       Lounge                      Lounges
# 28      77002                 Optical Shop                Optical Shops
# 29      77002                       Office                      Offices
# 30      77002             Dentist's Office            Dentist's Offices
# 31      77002                     Bus Line                    Bus Lines
# 32      77002                     Bus Line                    Bus Lines
# 33      77002                Deli / Bodega              Delis / Bodegas
# 34      77002                    Nightclub                   Nightclubs
# 35      77002         Gym / Fitness Center      Gyms or Fitness Centers
# 36      77002                     Building                    Buildings
# 37      77002                   Food Truck                  Food Trucks
# 38      77002                   Food Truck                  Food Trucks
# 39      77002                  Art Gallery                Art Galleries
# 40      77002              Conference Room             Conference Rooms
# 41      77002                   Food Truck                  Food Trucks
# 42      77002           Weight Loss Center          Weight Loss Centers
# 43      77002                     Building                    Buildings
# 44      77002                        Plaza                       Plazas
# 45      77002              Conference Room             Conference Rooms
# 46      77002                       Office                      Offices
# 47      77002                         Bank                        Banks
# 48      77002                  Bus Station                 Bus Stations
# 49      77002                     Bus Line                    Bus Lines
# 50      77002                      Parking                      Parking
# 51      77002                     Building                    Buildings
# 52      77002               Farmers Market              Farmers Markets
# 53      77002                     Building                    Buildings
# 54      77002  Professional & Other Places  Professional & Other Places
# 55      77002                  Bus Station                 Bus Stations
# 56      77002                       Bakery                     Bakeries
# 57      77004                  Coffee Shop                 Coffee Shops
# 58      77027                  Bus Station                 Bus Stations
# 59      77083                      Parking                      Parking
# 60      77083                          Gym                         Gyms
# 61      77009                     Bus Line                    Bus Lines
# 62      77023                   Auditorium                  Auditoriums
# 63      77042                         Bank                        Banks
# 64      77006           Miscellaneous Shop          Miscellaneous Shops
# 65      77007                         Bank                        Banks
#
#     Cluster Labels
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
# 5                2
# 6                2
# 7                2
# 8                2
# 9                2
# 10               2
# 11               2
# 12               2
# 13               2
# 14               2
# 15               2
# 16               2
# 17               2
# 18               2
# 19               2
# 20               2
# 21               2
# 22               2
# 23               2
# 24               2
# 25               2
# 26               2
# 27               2
# 28               2
# 29               2
# 30               2
# 31               2
# 32               2
# 33               2
# 34               2
# 35               2
# 36               2
# 37               2
# 38               2
# 39               2
# 40               2
# 41               2
# 42               2
# 43               2
# 44               2
# 45               2
# 46               2
# 47               2
# 48               2
# 49               2
# 50               2
# 51               2
# 52               2
# 53               2
# 54               2
# 55               2
# 56               2
# 57               5
# 58               3
# 59               8
# 60               8
# 61               6
# 62               0
# 63               1
# 64               4
# 65               7

# %%
newyork_cluster = cluster(newyork)
newyork_cluster
# Out:
# [4 7 2 8 3 0 6 1 5]
#                           id  \
# 0   4a676321f964a52051c91fe3
# 1   3fd66200f964a520d8f11ee3
# 2   4b57b0dff964a520293c28e3
# 3   4cd03c8ba03a9eb0cc58b103
# 4   4cd03c85a03a9eb0c158b103
# 5   5476b736498ec574d6261fb1
# 6   4bde139e6c1b9521fc4ead0f
# 7   4e727ee5e4cda03368ae650d
# 8   4c9bdfe87c096dcb6190bcd1
# 9   4cd03c87a03a9eb0c658b103
# 10  4e8cc9579adf8e728c47c270
# 11  5b333fe00d2be70039fd6232
# 12  4cd03c85a03a9eb0c058b103
# 13  4c96791758d4b60c10643b29
# 14  5ae8ee326f0aa2002c530890
# 15  4d7a47a07451236ae7c5defe
# 16  4ed4356b490137002c356322
# 17  4cd03c83a03a9eb0be58b103
# 18  50b4fa6fe4b04d4b63b37ebb
# 19  4db380c1cda1c57c8248bb4c
# 20  4d7bbe1b6152b60c8c7d8426
# 21  4d266026b818a35d89e1818a
# 22  4c98c477d799a1cd56f6b452
# 23  4e20700c1495f18f0343b915
# 24  4eefdf0f2c5b9617d9cae48e
# 25  4b79a5e8f964a52037082fe3
# 26  51b3b7da498efda7cefb2660
# 27  51a4bc7c498e469047be66d6
# 28  5d25d7fd3221cb002471e7c8
# 29  4fa93fdae4b07cb43c20da74
# 30  4c12c1e877cea59380a8cd60
# 31  4c9931d29f259eb08bf54885
# 32  4beec8b4e24d20a1a8587314
# 33  4c8e2987daa937045f0d4ab1
# 34  5228bfef11d240852944488e
# 35  58f6681daa6c9504bfc46721
# 36  504a293be4b01e50333444c9
# 37  51f68449498e1044dc6c70b5
# 38  51a75cf3498ec9d81dba70b0
# 39  4e7c9b6d62e1e879c397a16c
# 40  4bb63553f562ef3bcdca2f97
# 41  4cddee51aba88cfae43f3ed7
# 42  4d0110e48da26a311c68960c
# 43  4d8b8bc9f607a0937ca31687
# 44  4d10e42a6331a093f1725994
# 45  4e7e0dc7f7909ed0ec39af0c
# 46  4c0664d5761ac9b6b1d92074
# 47  4c1102f3ce57c928ecbb82d2
# 48  4dbef8f60437955ec0721ff4
# 49  3fd66200f964a5203ae51ee3
# 50  5ae3d3db3ba767002cf97a85
# 51  4cdd16f2cbed60fc34634f9f
# 52  4cb46b15eb65b1f71ee189cd
# 53  4f590573e4b09ba0e3ae71ce
# 54  50eac4e2e4b0b7b979c51ade
#
#                                                  name  \
# 0                                  New York City Hall
# 1                                      City Hall Park
# 2                        MTA Subway - City Hall (R/W)
# 3             Pace NYC Center for Academic Excellence
# 4                    Barns & Noble at Pace University
# 5                                            Music NY
# 6                               Printing House Square
# 7                              The Magic Costume Shop
# 8                  MTA - M22 Park Row & Spruce Street
# 9                                      Pace NYC Dyson
# 10                                      M103 bus stop
# 11                    Friedman, James & Buchsbaum LLP
# 12                        Pace NYC Schaeberle Theatre
# 13                                     The Pace Press
# 14                                         Pace Study
# 15                                            IDM Lab
# 16                                  Park Row Pizzeria
# 17                           Pace NYC Career Services
# 18            Pace University - Psychology Department
# 19                   15 Park Row Lobby, Food Delivery
# 20                           Sarwari Halal Food Truck
# 21                                  Pace Upward Bound
# 22                                    Pace SGA Office
# 23                        Plain Truth Publishing LTD.
# 24                               Pace Tutoring Center
# 25                                       NY Gift Shop
# 26                        Dahlia's Mexican Restaurant
# 27                         City Hall Council Chambers
# 28                                    City Hall Plaza
# 29                          The Horace Greeley Statue
# 30                                         Pizza-deli
# 31                         Fort Edward Farmers Market
# 32                 IRT Subway - City Hall (Abandoned)
# 33                            Department of Education
# 34                    Wafels & Dinges - Pagadder Cart
# 35                     Brooklyn Robot Foundry Tribeca
# 36                                              P1201
# 37                                      NYC Apartment
# 38  The Office of the Public Advocate for the City...
# 39                                 The Astor Building
# 40                                       Lawer Office
# 41                           MTA X27/X28 (Park Place)
# 42                               Nathan Hale Monument
# 43                   Kramer Dillof Livingston & Moore
# 44                       Law offices of Michael Block
# 45                               Jorge Guttlein, Esq.
# 46                 Mayor's Office of Contract Service
# 47                                    Halal Food Cart
# 48                              New York Film Academy
# 49         Spanish American Food (a.k.a. Cuchifritos)
# 50                     El Mexicano Restaurante & Cafe
# 51                                     Nevada Theater
# 52                                   The Cochran Firm
# 53                                      NK Architects
# 54                                    Law Firm Suites
#
#                                      address      city state country  \
# 0                             260 E Broadway  New York    NY      US
# 1                                17 Park Row  New York    NY      US
# 2                                 Warren St.  New York    NY      US
# 3                                 1 Pace Plz  New York    NY      US
# 4                                41 Park Row  New York    NY      US
# 5                             40 Ann St Fl 1  New York    NY      US
# 6           Avenue of the Finest at Park Row  New York    NY      US
# 7                                41 Park Row  New York    NY      US
# 8                                   Park Row  New York    NY      US
# 9                                41 Park Row  New York    NY      US
# 10                               33 Park Row  New York    NY      US
# 11                             132 Nassau St  New York    NY      US
# 12                               41 Park Row  New York    NY      US
# 13                       41 Park Row Ste 902  New York    NY      US
# 14                               41 Park Row  New York    NY      US
# 15                                1 Pace Plz  New York    NY      US
# 16                               38 Park Row  New York    NY      US
# 17                               41 Park Row  New York    NY      US
# 18                               41 Park Row  New York    NY      US
# 19                               15 Park Row  New York    NY      US
# 20                               8 Spruce St  New York    NY      US
# 21                          41 Park Row Fl 4  New York    NY      US
# 22                          41 Park Row #912  New York    NY      US
# 23                             139 Fulton St  New York    NY      US
# 24                               41 Park Row  New York    NY      US
# 25                              234 Canal St  New York    NY      US
# 26                          353 Greenwich St  New York    NY      US
# 27                                 City Hall  New York    NY      US
# 28                     Steve Flanders Square  New York    NY      US
# 29                            City Hall Park  New York    NY      US
# 30                                      1107  New York    NY      US
# 31  Broadway Bowl Rt 4 Across from Mcdonalds  New York    NY      US
# 32                            City Hall Park  New York    NY      US
# 33                            52 Chambers St  New York    NY      US
# 34                             Centre Street  New York    NY      US
# 35                             200 Church St  New York    NY      US
# 36                           Pace University  New York    NY      US
# 37                            85 Chambers St  New York    NY      US
# 38                               1 Centre St  New York    NY      US
# 39                              217 Broadway  New York    NY      US
# 40                      225 b'way 36th floor  New York    NY      US
# 41                              250 Broadway  New York    NY      US
# 42                            City Hall Park  New York    NY      US
# 43                              217 Broadway  New York    NY      US
# 44                              277 Broadway  New York    NY      US
# 45                              291 Broadway  New York    NY      US
# 46                              253 Broadway  New York    NY      US
# 47                                       723  New York    NY      US
# 48                             100 E 17th St  New York    NY      US
# 49                             351 E 13th St  New York    NY      US
# 50                               142 9th Ave  New York    NY      US
# 51                            Waterside Park  New York    NY      US
# 52                              233 Broadway  New York    NY      US
# 53                              233 Broadway  New York    NY      US
# 54                               11 Broadway  New York    NY      US
#
#      latitude  longitude postalCode                             type  \
# 0   40.712659 -74.005880      10002                        City Hall
# 1   40.712415 -74.006724      10038                             Park
# 2   40.713394 -74.006934      10038                    Metro Station
# 3   40.711887 -74.005789      10038                             Park
# 4   40.713389 -74.005944      10038                     Dessert Shop
# 5   40.710328 -74.007388      10038                College Classroom
# 6   40.712134 -74.004722      10038              Arts & Crafts Store
# 7   40.712463 -74.006728      10038                      Bus Station
# 8   40.712068 -74.005909      10038               Mexican Restaurant
# 9   40.712767 -74.006937      10038                    Jewelry Store
# 10  40.711437 -74.007113      10038                            Plaza
# 11  40.710869 -74.006442      10038                           Island
# 12  40.712463 -74.005772      10038              Monument / Landmark
# 13  40.712540 -74.006466      10038                         Bus Stop
# 14  40.711816 -74.006133      10038                      Kofte Place
# 15  40.712338 -74.005433      10038                      Pizza Place
# 16  40.712040 -74.006850      10038      Professional & Other Places
# 17  40.711665 -74.006200      10038                           Office
# 18  40.711882 -74.005743      10038                College Classroom
# 19  40.711947 -74.006678      10038                College Classroom
# 20  40.712020 -74.005657      10038                      College Lab
# 21  40.712144 -74.005726      10038                       Strip Club
# 22  40.712162 -74.005823      10038                           Office
# 23  40.712052 -74.006505      10038               Miscellaneous Shop
# 24  40.712154 -74.006064      10038                   Ice Cream Shop
# 25  40.712733 -74.005978      10013                        Gift Shop
# 26  40.718754 -74.010337      10013                           Office
# 27  40.712736 -74.005472      10007                        City Hall
# 28  40.712641 -74.006131      10007                            Plaza
# 29  40.712819 -74.004851      10007                       Public Art
# 30  40.712783 -74.005940      10007                      Pizza Place
# 31  40.713465 -74.006841      10007                   Farmers Market
# 32  40.712781 -74.004727      10007              Government Building
# 33  40.713593 -74.005347      10007                College Bookstore
# 34  40.712586 -74.004952      10007                      Music Venue
# 35  40.715143 -74.009962      10007                       Beer Store
# 36  40.712657 -74.005795      10007                         Bus Stop
# 37  40.712786 -74.005944      10007                  College Theater
# 38  40.712786 -74.005944      10007                      Bus Station
# 39  40.712003 -74.006701      10007                        Bookstore
# 40  40.712116 -74.005488      10007                       Food Truck
# 41  40.712218 -74.006856      10007                  Coworking Space
# 42  40.712010 -74.005686      10007  College Administrative Building
# 43  40.711756 -74.008849      10007                         Building
# 44  40.713368 -74.005379      10007                           Office
# 45  40.712141 -74.006192      10007                     Perfume Shop
# 46  40.713128 -74.007329      10007                           Lawyer
# 47  40.712778 -74.005943      10010                Indian Restaurant
# 48  40.713040 -74.005381      10003                College Classroom
# 49  40.730860 -73.983248      10003                  College Theater
# 50  40.675417 -74.000486      10011                         Building
# 51  40.714354 -74.005972      10011                   Student Center
# 52  40.712368 -74.007040      10279                           Office
# 53  40.712551 -74.007217      10279              Government Building
# 54  40.712222 -74.004934      10004                  Thai Restaurant
#
#                               plural  Cluster Labels
# 0                         City Halls               4
# 1                              Parks               1
# 2                     Metro Stations               1
# 3                              Parks               1
# 4                      Dessert Shops               1
# 5                 College Classrooms               1
# 6               Arts & Crafts Stores               1
# 7                       Bus Stations               1
# 8                Mexican Restaurants               1
# 9                     Jewelry Stores               1
# 10                            Plazas               1
# 11                           Islands               1
# 12             Monuments / Landmarks               1
# 13                         Bus Stops               1
# 14                      Kofte Places               1
# 15                      Pizza Places               1
# 16       Professional & Other Places               1
# 17                           Offices               1
# 18                College Classrooms               1
# 19                College Classrooms               1
# 20                      College Labs               1
# 21                       Strip Clubs               1
# 22                           Offices               1
# 23               Miscellaneous Shops               1
# 24                   Ice Cream Shops               1
# 25                        Gift Shops               6
# 26                           Offices               6
# 27                        City Halls               8
# 28                            Plazas               8
# 29                        Public Art               8
# 30                      Pizza Places               8
# 31                   Farmers Markets               8
# 32              Government Buildings               8
# 33                College Bookstores               8
# 34                      Music Venues               8
# 35                       Beer Stores               8
# 36                         Bus Stops               8
# 37                  College Theaters               8
# 38                      Bus Stations               8
# 39                        Bookstores               8
# 40                       Food Trucks               8
# 41                  Coworking Spaces               8
# 42  College Administrative Buildings               8
# 43                         Buildings               8
# 44                           Offices               8
# 45                     Perfume Shops               8
# 46                           Lawyers               8
# 47                Indian Restaurants               3
# 48                College Classrooms               7
# 49                  College Theaters               7
# 50                         Buildings               0
# 51                   Student Centers               0
# 52                           Offices               5
# 53              Government Buildings               5
# 54                  Thai Restaurants               2

# %%
cluster_map(ny_location, newyork_cluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cluster_map(hs_location, houston_cluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# On careful review of the results (business types and their rankings, clusters, etc) on a first glance, it is recommended to have more office buildings or office-related buildings, which if provided at a reasonable and relatively better price to others, will be highly patronized and resultingly profitable. However, on a deeper look, we also notice that the number of restaurants in those areas in both locations are very minimal. This means that, even though a lot of people report to those clusters on a daily basis to their respective jobs, they have to either bring their lunch from home or have to drive out away from that radius or cluster to get their lunch, or have it delivered. This shows a better business opportunity in these clusters in terms of a restaurant business. The type of cuisine offered by the restaurant(s) can then be decided upon via surveys or questionnaires, etc.
#
# So based on these results, I'd recommend two business types for my potential investors. These are;
# <br>
# 1. Office Buildings.
# 2. Restaurants.
#
# As detailed earlier, the Office buildings might be a reasonable option except that it might be a long shot based off the fact that they are already in high numbers (top ranked business type) in both locations. And on the other hand, the restaurant type based on cuisine would have to be determined (and which is outside the scope of this project).

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# In conclusion, the techniques, tools, methods, algorithms, libraries, etc, learned or acquired from this course has helped complete a project from start to finish, with specific consideration of introducing business  investment suggestions to potental investors.
